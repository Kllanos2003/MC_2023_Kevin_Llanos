# %%
import numpy as np
import matplotlib.pyplot as plt

xn=np.array([0, 1, 2, 3, 4, 5, 6, 7])

yn=np.array([3.5, 2.5, 3, 1.5, 2, 1.3, 1, 0.3])

n=len(xn)

Sum_x=sum(xn)
Sum_y=sum(yn)
Sum_xx=sum(xn**2)
Sum_xy=sum(xn*yn)

print(Sum_x, Sum_y, Sum_xx, Sum_xy)
# Out:
# 28 15.100000000000001 140 35.6

# %%
a_0=(Sum_xx*Sum_y-Sum_xy*Sum_x)/(n*Sum_xx-Sum_x**2)
a_1=(n*Sum_xy-Sum_x*Sum_y)/(n*Sum_xx-Sum_x**2)
print(a_0, a_1)

x=np.linspace(0, 7, 2)
y=a_0+a_1*x

plt.figure(1)

plt.scatter(xn, yn, color='r')
plt.grid(linestyle='dotted')
plt.plot(x, y, color='b')

plt.title(r'Regresión por Mínimos', fontsize=10)
plt.xlabel(r'x', fontsize=10)
plt.ylabel(r'y', fontsize=10)

plt.show()
# Out:
# 3.3249999999999993 -0.41071428571428586
