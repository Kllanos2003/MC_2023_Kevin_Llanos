# %%
import numpy as np
import matplotlib.pyplot as plt

xn=np.array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5])

yn=np.array([4.2, 6.5, 7.5, 8, 8.5, 8.8, 9, 9.1])

ly=1/yn
lx=1/xn

print(ly)
print(lx)

n=len(xn)

Sum_x=sum(lx)
Sum_y=sum(ly)
Sum_xx=sum(lx**2)
Sum_xy=sum(lx*ly)

print(Sum_x, Sum_y, Sum_xx, Sum_xy)
# Out:
# [0.23809524 0.15384615 0.13333333 0.125      0.11764706 0.11363636
#  0.11111111 0.10989011]
# [2.         0.66666667 0.4        0.28571429 0.22222222 0.18181818
#  0.15384615 0.13333333]
# 4.043600843600843 1.1025593687358395 4.809964081625754 0.7463531774226961

# %%
a_1=(n*Sum_xy-Sum_x*Sum_y)/(n*Sum_xx-Sum_x**2)
a_0= (Sum_y/n)-(a_1*Sum_x/n)

print(a_1)
print(a_0)

α=1/a_0
β=a_1/a_0

print(α)

x=np.linspace(0, 9)
y=α*(x/(β+x))

plt.figure(1)

plt.scatter(xn, yn, color='r')
plt.grid(linestyle='dotted')
plt.plot(x, y, color='b')

plt.title(r'Regresión por Mínimos', fontsize=10)
plt.xlabel(r'x', fontsize=10)
plt.ylabel(r'y', fontsize=10)

plt.show()
# Out:
# 0.06834990704206055
# 0.10327245337006552
# 9.683124273387886
