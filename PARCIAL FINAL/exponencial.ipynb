# %%
import numpy as np
import matplotlib.pyplot as plt

xn=np.array([1, 2, 3, 4, 5, 6, 7, 8])

yn=np.array([3.8, 4, 4.2, 4.6, 4.9, 5.3, 5.7, 6.1])

lny=np.log(yn)

print(lny)

n=len(xn)

Sum_x=sum(xn)
Sum_y=sum(lny)
Sum_xx=sum(xn**2)
Sum_xy=sum(xn*lny)

print(Sum_x, Sum_y, Sum_xx, Sum_xy)
# Out:
# [1.33500107 1.38629436 1.43508453 1.5260563  1.58923521 1.66770682
#  1.74046617 1.80828877]
# 36 12.48813322833103 204 59.119058921069296

# %%
from math import e

a_1=(n*Sum_xy-Sum_x*Sum_y)/(n*Sum_xx-Sum_x**2)
a_0= (Sum_y/n)-(a_1*Sum_x/n)

print(a_1)
print(a_0)

α=e**(a_0)
print(α)

x=np.linspace(0, 9)
y=α*np.e**(a_1*x)

plt.figure(1)

plt.scatter(xn, yn, color='r')
plt.grid(linestyle='dotted')
plt.plot(x, y, color='b')

plt.title(r'Regresión por Mínimos', fontsize=10)
plt.xlabel(r'x', fontsize=10)
plt.ylabel(r'y', fontsize=10)

plt.show()
# Out:
# 0.06958236651380137
# 1.2478960042292726
# 3.483007010747613

# %% [markdown]
# ESTE ES EL MEJOR
