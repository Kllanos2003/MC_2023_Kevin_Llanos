# %%
import numpy as np
import matplotlib.pyplot as plt

xn=np.array([1, 2, 3, 4, 5, 6, 7, 8])

yn=np.array([3.8, 4, 4.2, 4.6, 4.9, 5.3, 5.7, 6.1])

ly=1/yn
lx=1/xn

print(ly)
print(lx)

n=len(xn)

Sum_x=sum(lx)
Sum_y=sum(ly)
Sum_xx=sum(lx**2)
Sum_xy=sum(lx*ly)

print(Sum_x, Sum_y, Sum_xx, Sum_xy)
# Out:
# [0.26315789 0.25       0.23809524 0.2173913  0.20408163 0.18867925
#  0.1754386  0.16393443]
# [1.         0.5        0.33333333 0.25       0.2        0.16666667
#  0.14285714 0.125     ]
# 2.7178571428571425 1.7007783378367225 1.527422052154195 0.6396881275202859

# %%
a_1=(n*Sum_xy-Sum_x*Sum_y)/(n*Sum_xx-Sum_x**2)
a_0= (Sum_y/n)-(a_1*Sum_x/n)

print(a_1)
print(a_0)

α=1/a_0
β=a_1/a_0

print(α)

x=np.linspace(0, 9)
y=α*(x/(β+x))

plt.figure(1)

plt.scatter(xn, yn, color='r')
plt.grid(linestyle='dotted')
plt.plot(x, y, color='b')

plt.title(r'Regresión por Mínimos', fontsize=10)
plt.xlabel(r'x', fontsize=10)
plt.ylabel(r'y', fontsize=10)

plt.show()
# Out:
# 0.10243543824861603
# 0.17779668128887746
# 5.624401944686679
